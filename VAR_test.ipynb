# %%
# %matplotlib inline

# %%
import VAR.py
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-3-2abdcc131069> in <module>()
# ----> 1 import VAR.py
#
# ImportError: No module named 'VAR.py'; 'VAR' is not a package
